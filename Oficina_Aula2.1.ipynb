# %%
#Importe as bibliotecas pandas, matplotlib, seaborn e use o comando mágico %matplotlib inline para exibir as visualizações no notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Carregue os dados em um DataFrame
filmes_uri = 'https://raw.githubusercontent.com/emanueles/datavis-course/master/assets/files/observable/movies.json'
filmes = pd.read_json(filmes_uri)
filmes.head()
# Out:
#                                           Film  Year      Genre  \
# 0  Harry Potter and the Deathly Hallows Part 2  2011    Fantasy
# 1                         Mission Impossible 4  2011     Action
# 2                                  Toy Story 3  2010  Animation
# 3                                         2012  2009     Action
# 4                          Alice in Wonderland  2010  Adventure
#
#    Worldwide_Gross_M  Budget_M
# 0               1328       125
# 1                689       145
# 2               1063       200
# 3                768       200
# 4               1024       200

# %%
#Mostrar orçamento de todos os filmes
plt.figure(figsize=(10,20))
plt.title('orçamento de todos os filmes')
sns.barplot(x="Budget_M", y="Film", color = 'b', ci = 'sd', data=filmes)
plt.show()

# %%
#Mostrar o filme com o maior orçamento
df[df['Budget_M'] >= 300]
# Out:
#                                         Film  Year   Genre  Worldwide_Gross_M  \
# 16  Pirates of the Caribbean: At World's End  2007  Action                961
#
#     Budget_M
# 16       300

# %%
#Mostrar o filme com o menor orçamento
df[df['Budget_M'] <= 50]
# Out:
#                            Film  Year  Genre  Worldwide_Gross_M  Budget_M
# 13  The Twilight Saga: New Moon  2009  Drama                710        50

# %%
#Mostrar bilheteria de todos os filmes
plt.figure(figsize=(10,20))
plt.title('bilheteria de todos os filmes')
sns.barplot(x="Worldwide_Gross_M", y="Film", color = 'b', ci = 'sd', data=filmes)
plt.show()

# %%
#Mostrar o filme com a maior bilheteria
df[df['Worldwide_Gross_M'] >= 2500]
# Out:
#      Film  Year   Genre  Worldwide_Gross_M  Budget_M
# 6  Avatar  2009  Action               2784       237

# %%
#Mostrar o filme com a menor bilheteria
df[df['Worldwide_Gross_M'] < 1000]
# Out:
#                                                  Film  Year      Genre  \
# 1                                Mission Impossible 4  2011     Action
# 3                                                2012  2009     Action
# 5                                     The Dark Knight  2008   Thriller
# 8                                          Iron Man 2  2010     Action
# 9                                     Kung Fu Panda 2  2011  Animation
# 10                                    Shrek the Third  2007  Animation
# 11             Harry Potter and the Half-Blood Prince  2009  Adventure
# 12                                          Inception  2010     Action
# 13                        The Twilight Saga: New Moon  2009      Drama
# 14        Harry Potter and the Deathly Hallows Part 1  2010  Adventure
# 15                                                 Up  2009  Animation
# 16           Pirates of the Caribbean: At World's End  2007     Action
# ...

# %%
#Quantidade de filmes por gênero em cada ano
plt.figure(figsize=(15,8))
plt.title('Filmes por gênero em cada ano')
sns.countplot(x="Year", hue= 'Genre', data=filmes)
plt.show()

# %%
#Menos filmes de ação
#Não consigo especificar essa informação. Preciso de auxilio
df[df['Year'] <= 2]
# Out:
# Empty DataFrame
# Columns: [Film, Year, Genre, Worldwide_Gross_M, Budget_M]
# Index: []

# %%
#Menos filmes de animação
#Não consigo especificar essa informação. Preciso de auxilio
df[df['Year'] <= 2.0]
# Out:
# Empty DataFrame
# Columns: [Film, Year, Genre, Worldwide_Gross_M, Budget_M]
# Index: []

# %%
#média de orçamento de filmes por gênero em cada ano
plt.figure(figsize=(15,8))
plt.title('Média de bilheteria por gênero em cada ano')
sns.barplot(x="Year", y = 'Budget_M' , ci = None, hue= 'Genre', data=filmes)
plt.show()

# %%
#Em que ano os filmes de ação tiveram maior média de orçamento
#Não consigo especificar essa informação. Preciso de auxilio
df[df['Year'] <= 2.0]
# Out:
# Empty DataFrame
# Columns: [Film, Year, Genre, Worldwide_Gross_M, Budget_M]
# Index: []

# %%
#Em que ano os filmes de animação tiveram a maior média de orçamento
#Não consigo especificar essa informação. Preciso de auxilio
df[df['Year'] <= 2.0]
